# %%
import pandas as pd
import os
import numpy as np
from datetime import datetime, timedelta
import pytz

from sklearn.impute import SimpleImputer

# %% [markdown]
# Global variables

# %%
CECS_698_PATH = '/content/drive/MyDrive/CECS 698 - Data Analysis/'

EMBRACEPLUS_TRIMMED_PATH = os.path.join(CECS_698_PATH, 'EmbracePlus Trimmed')
EMBRACEPLUS_COMBINED_PATH = os.path.join(CECS_698_PATH, 'EmbracePlus Combined')

GAZEPOINT_TRIMMED_PATH = os.path.join(CECS_698_PATH, 'Gazepoint Trimmed')

PARTICIPANTS = [i for i in range(4, 27)]

GAZEPOINT_TUMBLING_WINDOW_DGM = os.path.join(CECS_698_PATH, 'Gazepoint Tumbling Window DGM')
GAZEPOINT_DGM_TIMESTAMP_LABELED = os.path.join(CECS_698_PATH, 'Gazepoint DGM Timestamp Labeled')

MERGED_DATA = os.path.join(CECS_698_PATH, 'Merged Data')

# Particpants ids to exclude on specific assessments
EASY_ASSESSMENT_EXCLUDE = [11, 22]
HARD_ASSESSMENT_EXCLUDE = [15, 21]

# %% [markdown]
# # EmbracePlus ⌚

# %% [markdown]
# ## Combining Datasets

# %%
# Create a new directory to store combined data: '/content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined'
if not os.path.exists(EMBRACEPLUS_COMBINED_PATH):
    os.mkdir(EMBRACEPLUS_COMBINED_PATH)

if os.path.exists(EMBRACEPLUS_TRIMMED_PATH):
    for p in PARTICIPANTS:
        print(f"Participant {p}")

        source = os.path.join(EMBRACEPLUS_TRIMMED_PATH, f'Participant {p}')
        dest = os.path.join(EMBRACEPLUS_COMBINED_PATH, f'Participant {p}') # Create subdirectories within new '/EmbracePlus Combined' directory
        if not os.path.exists(dest):
            os.mkdir(dest)


        ################################################ Easy Assessments ################################################

        df_eda_easy = pd.read_csv(os.path.join(source, 'eda_easy.csv'))[['timestamp_unix', 'eda_scl_usiemens']]
        # df_prv_easy = pd.read_csv(os.path.join(source, 'prv_easy.csv'))[['prv_rmssd_ms']]
        df_pulse_rate_easy = pd.read_csv(os.path.join(source, 'pulse-rate_easy.csv'))[['pulse_rate_bpm']]
        # df_respiratory_rate_easy = pd.read_csv(os.path.join(source, 'respiratory-rate_easy.csv'))[['respiratory_rate_brpm']]
        df_temperature_easy = pd.read_csv(os.path.join(source, 'temperature_easy.csv'))[['temperature_celsius']]


        df_easy_combined = pd.concat([df_eda_easy, df_pulse_rate_easy, df_temperature_easy], axis=1)
        # df_easy_combined = pd.concat([df_eda_easy, df_prv_easy, df_pulse_rate_easy, df_respiratory_rate_easy, df_temperature_easy], axis=1)
        df_easy_combined.to_csv(os.path.join(dest, 'EmbracePlus_easy_combined.csv'), index=False)
        print(f"\tSuccessfully saved combined easy data into {dest}")

        ################################################ Hard Assessments ################################################

        df_eda_hard = pd.read_csv(os.path.join(source, 'eda_hard.csv'))[['timestamp_unix', 'eda_scl_usiemens']]
        # df_prv_hard = pd.read_csv(os.path.join(source, 'prv_hard.csv'))[['prv_rmssd_ms']]
        df_pulse_rate_hard = pd.read_csv(os.path.join(source, 'pulse-rate_hard.csv'))[['pulse_rate_bpm']]
        # df_respiratory_rate_hard = pd.read_csv(os.path.join(source, 'respiratory-rate_hard.csv'))[['respiratory_rate_brpm']]
        df_temperature_hard = pd.read_csv(os.path.join(source, 'temperature_hard.csv'))[['temperature_celsius']]

        df_hard_combined = pd.concat([df_eda_hard, df_pulse_rate_hard, df_temperature_hard], axis=1)
        # df_hard_combined = pd.concat([df_eda_hard, df_prv_hard, df_pulse_rate_hard, df_respiratory_rate_hard, df_temperature_hard], axis=1)
        df_hard_combined.to_csv(os.path.join(dest, 'EmbracePlus_hard_combined.csv'), index=False)
        print(f"\tSuccessfully saved combined hard data into {dest}\n")

else:
    print(f"{EMBRACEPLUS_TRIMMED_PATH} does not exist.")
# Out:
# Participant 4
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 4
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 4
#
# Participant 5
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 5
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 5
#
# Participant 6
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 6
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 6
#
# Participant 7
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 7
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 7
#
# Participant 8
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 8
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 8
#
# Participant 9
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 9
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 9
#
# Participant 10
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 10
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 10
#
# Participant 11
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 11
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 11
#
# Participant 12
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 12
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 12
#
# Participant 13
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 13
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 13
#
# Participant 14
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 14
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 14
#
# Participant 15
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 15
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 15
#
# Participant 16
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 16
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 16
#
# Participant 17
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 17
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 17
#
# Participant 18
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 18
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 18
#
# Participant 19
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 19
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 19
#
# Participant 20
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 20
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 20
#
# Participant 21
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 21
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 21
#
# Participant 22
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 22
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 22
#
# Participant 23
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 23
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 23
#
# Participant 24
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 24
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 24
#
# Participant 25
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 25
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 25
#
# Participant 26
# 	Successfully saved combined easy data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 26
# 	Successfully saved combined hard data into /content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 26

# %% [markdown]
# ## Viewing Null Values

# %%
for participant in os.listdir(EMBRACEPLUS_COMBINED_PATH):
    print(f"{participant}:")
    for file in os.listdir(os.path.join(EMBRACEPLUS_COMBINED_PATH, participant)):
        print(f"\t{file}", end=" ")
        df = pd.read_csv(os.path.join(EMBRACEPLUS_COMBINED_PATH, participant, file))
        total_rows = len(df)

        # Finding columns with null values and their null count
        columns_with_nulls = df.isnull().sum()
        columns_with_nulls = columns_with_nulls[columns_with_nulls > 0]  # Filter columns with at least one null

        # Formatting the output
        output = ", ".join([f"{col} ({null_count}/{total_rows})" for col, null_count in columns_with_nulls.items()])

        # Printing the result
        print(f"Columns with null values: {output}")
# Out:
# Participant 4:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 5:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 6:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 7:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 8:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 9:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 10:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# Participant 11:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 12:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 13:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 14:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 15:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 16:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 17:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# Participant 18:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 19:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 20:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values: eda_scl_usiemens (1/22), pulse_rate_bpm (1/22), temperature_celsius (1/22)
# Participant 21:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 22:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 23:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# 	EmbracePlus_easy_combined.csv Columns with null values: eda_scl_usiemens (1/10), pulse_rate_bpm (1/10), temperature_celsius (1/10)
# Participant 24:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 25:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 26:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:

# %% [markdown]
# So far, participants 20 (Hard) and 23 (Easy) have null values. We will impute these null values using scikitlearn's `SimpleImputer`

# %%
df = pd.read_csv('/content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 20/EmbracePlus_hard_combined.csv')

imputer = SimpleImputer(strategy='median')
imputed_data = imputer.fit_transform(df)
df = pd.DataFrame(imputed_data, columns=df.columns)

df.to_csv('/content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 20/EmbracePlus_hard_combined.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 23/EmbracePlus_easy_combined.csv')

imputer = SimpleImputer(strategy='median')
imputed_data = imputer.fit_transform(df)
df = pd.DataFrame(imputed_data, columns=df.columns)

df.to_csv('/content/drive/MyDrive/CECS 698 - Data Analysis/EmbracePlus Combined/Participant 23/EmbracePlus_easy_combined.csv', index=False)

# %%
for participant in os.listdir(EMBRACEPLUS_COMBINED_PATH):
    print(f"{participant}:")
    for file in os.listdir(os.path.join(EMBRACEPLUS_COMBINED_PATH, participant)):
        print(f"\t{file}", end=" ")
        df = pd.read_csv(os.path.join(EMBRACEPLUS_COMBINED_PATH, participant, file))
        total_rows = len(df)

        # Finding columns with null values and their null count
        columns_with_nulls = df.isnull().sum()
        columns_with_nulls = columns_with_nulls[columns_with_nulls > 0]  # Filter columns with at least one null

        # Formatting the output
        output = ", ".join([f"{col} ({null_count}/{total_rows})" for col, null_count in columns_with_nulls.items()])

        # Printing the result
        print(f"Columns with null values: {output}")
# Out:
# Participant 4:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 5:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 6:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 7:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 8:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 9:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 10:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# Participant 11:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 12:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 13:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 14:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 15:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 16:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 17:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# Participant 18:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 19:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 20:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 21:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 22:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 23:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# Participant 24:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 25:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:
# Participant 26:
# 	EmbracePlus_easy_combined.csv Columns with null values:
# 	EmbracePlus_hard_combined.csv Columns with null values:

# %% [markdown]
# # Gazepoint 👁

# %% [markdown]
# ## Labeling timestamps on all_window_DGMs file

# %% [markdown]
# I've taken the currently trimmed gaze data from `/Gazepoint Trimmed` directory and manually put them all into [BEACH Gaze](https://github.com/TheD2Lab/BEACH-Gaze) to get Descriptive Gaze Measures (DGMs) using the Tumbling Window approach (Window size 10 seconds). All of the data generataed by BEACH Gaze are put in the `/Gazepoint Tumbling Window DGM` directory containing subdirectories per participant, per assessment.
#  - (Ex:  `/Gazepoint Tumbling Window DGM/Participant 10/results/all_gaze_easy` and `/Gazepoint Tumbling Window DGM/Participant 10/results/all_gaze_hard`
#
# This script below is used add timestamps to each `all_window_DGMs.csv` file per participant.
#
# ⚠ **WARNING: THIS WILL TAKE A WHILE TO RUN. RUN IT ONCE IF THESE FILES CREATED ALREADY EXIST**

# %%
all_participants = os.listdir(GAZEPOINT_TUMBLING_WINDOW_DGM)
all_participants = sorted(all_participants, key=lambda x: int(x.replace("Participant ", "")))


# File path created to save modified data
if not os.path.exists(GAZEPOINT_DGM_TIMESTAMP_LABELED):
    os.mkdir(GAZEPOINT_DGM_TIMESTAMP_LABELED)

# -------------------- Labeling DGM files with timestamp_pst and timestamp_unix --------------------
for p in PARTICIPANTS:
    print(f"Participant {p}")

    # Creating subdirectory per participant
    if not os.path.exists(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, f'Participant {p}')):
        os.mkdir(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, f'Participant {p}'))

    results_dir = os.path.join(GAZEPOINT_TUMBLING_WINDOW_DGM, f'Participant {p}', 'results')
    for all_gaze_dir in os.listdir(results_dir):
        window = []
        timestamp_unix = []
        timestamp_pst = []

        tumbling_dir = os.path.join(results_dir, all_gaze_dir, 'tumbling')
        print(f"\t{tumbling_dir}")

        # Dataframe contains combination of ALL windows together
        all_window_DGMs_df = pd.read_csv(os.path.join(tumbling_dir, 'all_window_DGMs.csv'))

        windows_dirs = os.listdir(tumbling_dir)
        windows_dirs.remove('all_window_DGMs.csv')
        sorted_windows_dirs = sorted(windows_dirs, key=lambda x: int(x.replace("window", ""))) # window1, window2, window3, etc...



        # Getting the last timestamp (UNIX and PST) from each window, and adding that to current all_window_DGMs file

        for i, w in enumerate(sorted_windows_dirs):
            window_df = pd.read_csv(os.path.join(tumbling_dir, w, f'window{i + 1}.csv'))

            window.append(sorted_windows_dirs[i])
            timestamp_unix.append(window_df.iloc[-1]['timestamp_unix'])
            timestamp_pst.append(window_df.iloc[-1]['timestamp_pst'])


            added_columns = pd.DataFrame({
                'window': window,
                'timestamp_unix': timestamp_unix,
                'timestamp_pst': timestamp_pst
            })

        all_window_DGMs_df_mod = pd.concat([all_window_DGMs_df, added_columns], axis=1)
        # print(f"\t\t{len(window)} {len(timestamp_unix)} {len(timestamp_pst)} {len(all_window_DGMs_df)}")

        # Import all_window_DGMs_df_mod into '/Gazepoint DGM Timestamp Labeled'
        if tumbling_dir.split('/')[-2] == 'all_gaze_hard':
            all_window_DGMs_df_mod.to_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, f'Participant {p}', 'all_gaze_hard.csv'), index=False)
            print('\t\tSuccessfully saved all_gaze_hard.csv', end=' ')

        elif tumbling_dir.split('/')[-2] == 'all_gaze_easy':
            all_window_DGMs_df_mod.to_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, f'Participant {p}', 'all_gaze_easy.csv'), index=False)
            print('\t\tSuccessfully saved all_gaze_easy.csv', end=' ')

        print(f"\033[94m [[{all_window_DGMs_df_mod.iloc[0]['timestamp_pst']} - {all_window_DGMs_df_mod.iloc[-1]['timestamp_pst']}]] \033[0m")
# Out:
# Participant 4
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 4/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[05:02:47 PM - 05:29:15 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 4/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[04:40:51 PM - 04:51:55 PM]]
# Participant 5
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 5/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[10:28:44 AM - 10:55:56 AM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 5/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[10:10:38 AM - 10:18:55 AM]]
# Participant 6
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 6/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[07:26:41 PM - 07:33:34 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 6/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[07:42:04 PM - 08:00:44 PM]]
# Participant 7
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 7/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[11:44:10 AM - 11:59:46 AM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 7/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[11:31:51 AM - 11:38:14 AM]]
# Participant 8
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 8/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[02:10:56 PM - 02:40:11 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 8/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[01:53:43 PM - 02:01:51 PM]]
# Participant 9
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 9/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[03:52:16 PM - 03:58:44 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 9/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[04:05:18 PM - 04:30:50 PM]]
# Participant 10
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 10/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[06:02:24 PM - 06:11:33 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 10/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[06:19:58 PM - 06:39:16 PM]]
# Participant 11
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 11/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[11:50:48 AM - 12:13:16 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 11/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[11:34:54 AM - 11:41:04 AM]]
# Participant 12
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 12/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[01:44:01 PM - 02:05:08 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 12/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[01:26:09 PM - 01:35:14 PM]]
# Participant 13
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 13/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[01:29:06 PM - 01:43:01 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 13/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[01:51:23 PM - 02:27:10 PM]]
# Participant 14
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 14/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[11:31:14 AM - 11:54:59 AM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 14/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[12:03:18 PM - 12:12:39 PM]]
# Participant 15
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 15/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[07:23:28 PM - 07:44:47 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 15/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[08:00:08 PM - 08:04:51 PM]]
# Participant 16
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 16/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[12:05:35 PM - 12:14:20 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 16/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[11:37:57 AM - 11:57:25 AM]]
# Participant 17
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 17/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[01:43:18 PM - 01:51:20 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 17/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[01:25:26 PM - 01:34:04 PM]]
# Participant 18
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 18/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[01:10:59 PM - 01:31:56 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 18/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[01:40:26 PM - 01:47:32 PM]]
# Participant 19
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 19/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[01:39:27 PM - 01:44:35 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 19/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[01:19:22 PM - 01:26:37 PM]]
# Participant 20
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 20/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[12:04:32 PM - 12:12:50 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 20/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[11:34:11 AM - 11:56:07 AM]]
# Participant 21
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 21/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[01:29:26 PM - 01:57:53 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 21/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[02:12:13 PM - 02:21:28 PM]]
# Participant 22
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 22/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[12:54:11 PM - 01:22:07 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 22/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[01:31:43 PM - 01:43:19 PM]]
# Participant 23
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 23/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[03:12:33 PM - 03:22:12 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 23/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[02:27:24 PM - 03:01:16 PM]]
# Participant 24
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 24/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[05:38:08 PM - 05:58:29 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 24/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[05:20:43 PM - 05:28:13 PM]]
# Participant 25
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 25/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[07:33:10 PM - 08:00:07 PM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 25/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[08:18:51 PM - 08:28:28 PM]]
# Participant 26
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 26/results/all_gaze_easy/tumbling
# 		Successfully saved all_gaze_easy.csv  [[10:58:52 AM - 11:03:36 AM]]
# 	/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint Tumbling Window DGM/Participant 26/results/all_gaze_hard/tumbling
# 		Successfully saved all_gaze_hard.csv  [[10:31:23 AM - 10:49:13 AM]]

# %% [markdown]
# ## Getting rid of irrelevant columns

# %%
deleted_columns = [
    'total_number_of_l_mouse_clicks',
    'beginning_timestamp',
    'ending_timestamp',
    'window_duration',
    'initial_seconds_elapsed_since_start',
    'final_seconds_elapsed_since_start',
    'timestamp_pst'
]

for participant_dir in os.listdir(GAZEPOINT_DGM_TIMESTAMP_LABELED):
    for file in os.listdir(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir)):
        df = pd.read_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir, file))
        df.drop(deleted_columns, axis=1, inplace=True)

        # Override current files with new files after dropping columns
        df.to_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir, file), index=False)

# %% [markdown]
# ## Getting rid of null values

# %%
for participant_dir in os.listdir(GAZEPOINT_DGM_TIMESTAMP_LABELED):
    print(f"{participant_dir}:")
    for file in os.listdir(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir)):
        print(f"\t{file}", end=" ")
        df = pd.read_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir, file))
        total_rows = len(df)

        # Finding columns with null values and their null count
        columns_with_nulls = df.isnull().sum()
        columns_with_nulls = columns_with_nulls[columns_with_nulls > 0]  # Filter columns with at least one null

        # Printing the result
        print(f"{len(columns_with_nulls)} columns with null values")
# Out:
# Participant 4:
# 	all_gaze_hard.csv 5 columns with null values
# 	all_gaze_easy.csv 42 columns with null values
# Participant 5:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 6:
# 	all_gaze_hard.csv 1 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 7:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 8:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 1 columns with null values
# Participant 9:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 10:
# 	all_gaze_hard.csv 45 columns with null values
# 	all_gaze_easy.csv 45 columns with null values
# Participant 11:
# 	all_gaze_easy.csv 42 columns with null values
# 	all_gaze_hard.csv 42 columns with null values
# Participant 12:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 13:
# 	all_gaze_easy.csv 5 columns with null values
# 	all_gaze_hard.csv 38 columns with null values
# Participant 14:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 45 columns with null values
# Participant 15:
# 	all_gaze_hard.csv 42 columns with null values
# 	all_gaze_easy.csv 45 columns with null values
# Participant 16:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 36 columns with null values
# Participant 17:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 18:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 19:
# 	all_gaze_easy.csv 45 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 20:
# 	all_gaze_hard.csv 42 columns with null values
# 	all_gaze_easy.csv 45 columns with null values
# Participant 21:
# 	all_gaze_easy.csv 11 columns with null values
# 	all_gaze_hard.csv 42 columns with null values
# Participant 22:
# 	all_gaze_easy.csv 42 columns with null values
# 	all_gaze_hard.csv 42 columns with null values
# Participant 23:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 24:
# 	all_gaze_easy.csv 12 columns with null values
# 	all_gaze_hard.csv 12 columns with null values
# Participant 25:
# 	all_gaze_hard.csv 1 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 26:
# 	all_gaze_hard.csv 12 columns with null values
# 	all_gaze_easy.csv 0 columns with null values

# %% [markdown]
# There are many columns with null values. Looking at the info of all columns. All columns (Except for `window` and `timestamp_pst` are `float64` or `int64`. We can impute null values by their medians

# %%
ex_df = pd.read_csv('/content/drive/MyDrive/CECS 698 - Data Analysis/Gazepoint DGM Timestamp Labeled/Participant 10/all_gaze_easy.csv')
ex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 63 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   total_number_of_fixations         56 non-null     int64
#  1   sum_of_all_fixation_duration_s    56 non-null     float64
#  2   mean_fixation_duration_s          54 non-null     float64
#  3   median_fixation_duration_s        54 non-null     float64
#  4   stdev_of_fixation_durations_s     54 non-null     float64
#  5   min_fixation_duration_s           54 non-null     float64
#  6   max_fixation_duration_s           54 non-null     float64
#  7   total_number_of_saccades          56 non-null     int64
#  8   sum_of_all_saccade_lengths        56 non-null     float64
#  9   mean_saccade_length               54 non-null     float64
#  10  median_saccade_length             54 non-null     float64
#  11  stdev_of_saccade_lengths          54 non-null     float64
#  12  min_saccade_length                54 non-null     float64
#  13  max_saccade_length                54 non-null     float64
#  14  sum_of_all_saccade_durations      56 non-null     float64
#  15  mean_saccade_duration             54 non-null     float64
#  16  median_saccade_duration           54 non-null     float64
#  17  stdev_of_saccade_durations        54 non-null     float64
#  18  min_saccade_duration              54 non-null     float64
#  19  max_saccade_duration              54 non-null     float64
#  20  sum_of_all_saccade_amplitudes     56 non-null     float64
#  21  mean_saccade_amplitude            54 non-null     float64
#  22  median_saccade_amplitude          54 non-null     float64
#  23  stdev_of_saccade_amplitude        54 non-null     float64
#  24  min_saccade_amplitude             54 non-null     float64
#  25  max_saccade_amplitude             54 non-null     float64
#  26  scanpath_duration                 56 non-null     float64
#  27  fixation_to_saccade_ratio         54 non-null     float64
#  28  sum_peak_saccade_velocity         56 non-null     float64
#  29  mean_peak_saccade_velocity        54 non-null     float64
#  30  median_peak_saccade_velocity      54 non-null     float64
#  31  std_peak_saccade_velocity         54 non-null     float64
#  32  min_peak_saccade_velocity         54 non-null     float64
#  33  max_peak_saccade_velocity         54 non-null     float64
#  34  sum_mean_saccade_velocity         56 non-null     float64
#  35  mean_mean_saccade_velocity        54 non-null     float64
#  36  median_mean_saccade_velocity      54 non-null     float64
#  37  std_mean_saccade_velocity         54 non-null     float64
#  38  min_mean_saccade_velocity         54 non-null     float64
#  39  max_mean_saccade_velocity         54 non-null     float64
#  40  sum_of_all_absolute_degrees       56 non-null     float64
#  41  mean_absolute_degree              54 non-null     float64
#  42  median_absolute_degree            54 non-null     float64
#  43  stdev_of_absolute_degrees         54 non-null     float64
#  44  min_absolute_degree               54 non-null     float64
#  45  max_absolute_degree               54 non-null     float64
#  46  sum_of_all_relative_degrees       56 non-null     float64
#  47  mean_relative_degree              54 non-null     float64
#  48  median_relative_degree            54 non-null     float64
#  49  stdev_of_relative_degrees         54 non-null     float64
#  50  min_relative_degree               54 non-null     float64
#  51  max_relative_degree               54 non-null     float64
#  52  convex_hull_area                  54 non-null     float64
#  53  stationary_entropy                56 non-null     float64
#  54  transition_entropy                56 non-null     float64
#  55  total_number_of_blinks            56 non-null     int64
#  56  average_blink_rate_per_minute     56 non-null     float64
#  57  total_number_of_valid_recordings  56 non-null     int64
#  58  average_pupil_size_of_left_eye    55 non-null     float64
#  59  average_pupil_size_of_right_eye   55 non-null     float64
#  60  average_pupil_size_of_both_eyes   55 non-null     float64
#  61  window                            56 non-null     object
#  62  timestamp_unix                    56 non-null     int64
# dtypes: float64(57), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
# Getting rid of null values
imputer = SimpleImputer(strategy='median')

for participant_dir in os.listdir(GAZEPOINT_DGM_TIMESTAMP_LABELED):
    for file in os.listdir(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir)):
        df = pd.read_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir, file))

        numeric_cols = df.select_dtypes(include=['number']).columns
        df[numeric_cols] = imputer.fit_transform(df[numeric_cols])

        # Override current files with new files after imputing null values
        df.to_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir, file), index=False)

# %%
for participant_dir in os.listdir(GAZEPOINT_DGM_TIMESTAMP_LABELED):
    print(f"{participant_dir}:")
    for file in os.listdir(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir)):
        print(f"\t{file}", end=" ")
        df = pd.read_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, participant_dir, file))
        total_rows = len(df)

        # Finding columns with null values and their null count
        columns_with_nulls = df.isnull().sum()
        columns_with_nulls = columns_with_nulls[columns_with_nulls > 0]  # Filter columns with at least one null

        # Printing the result
        print(f"{len(columns_with_nulls)} columns with null values")
# Out:
# Participant 4:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 5:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 6:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 7:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 8:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 9:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 10:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 11:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 12:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 13:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 14:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 15:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 16:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 17:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 18:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 19:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 20:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 21:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 22:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 23:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 24:
# 	all_gaze_easy.csv 0 columns with null values
# 	all_gaze_hard.csv 0 columns with null values
# Participant 25:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values
# Participant 26:
# 	all_gaze_hard.csv 0 columns with null values
# 	all_gaze_easy.csv 0 columns with null values

# %% [markdown]
# # Merging both EmbracePlus and Gazepoint Data 🛠

# %% [markdown]
# NOTE: Some null values are generated due to the differing start times of the merged datasets, even after interpolation. Specifically, the dataset that starts earlier will have null values until its timestamps align with those of the later-starting dataset. This is why we use `dropna()` as seen below

# %%
# File path created to save merged data
if not os.path.exists(MERGED_DATA):
    os.mkdir(MERGED_DATA)

# Merging data for all participants
pacific_timezone = pytz.timezone('US/Pacific')

for p in PARTICIPANTS:
    print(f"Participant {p}")

    participant_dir = os.path.join(MERGED_DATA, f"Participant {p}")
    if not os.path.exists(participant_dir):
        os.mkdir(participant_dir)

    # -------------------- Merging datasets during easy assessments --------------------
    easy_EP_df = pd.read_csv(os.path.join(EMBRACEPLUS_COMBINED_PATH, f'Participant {p}', 'EmbracePlus_easy_combined.csv'))
    easy_GP_df = pd.read_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, f'Participant {p}', 'all_gaze_easy.csv'))
    df_easy_merged = pd.merge(easy_EP_df, easy_GP_df, on="timestamp_unix", how="outer")
    df_easy_merged.drop('window', axis=1, inplace=True) # No longer need this column, as it was used for validation

    numeric_cols = df_easy_merged.select_dtypes(include=['number']).columns
    for n in numeric_cols:
        df_easy_merged[n] = df_easy_merged[n].interpolate()

    df_easy_merged = df_easy_merged.dropna().reset_index(drop=True) # Droping null values

    df_easy_merged.to_csv(os.path.join(participant_dir, f"participant{p}_easy_assessment.csv"), index=False)
    print('\t\tSuccessfully merged easy asessment data')

    # -------------------- Merging datasets during hard assessments --------------------
    hard_EP_df = pd.read_csv(os.path.join(EMBRACEPLUS_COMBINED_PATH, f'Participant {p}', 'EmbracePlus_hard_combined.csv'))
    hard_GP_df = pd.read_csv(os.path.join(GAZEPOINT_DGM_TIMESTAMP_LABELED, f'Participant {p}', 'all_gaze_hard.csv'))
    df_hard_merged = pd.merge(hard_EP_df, hard_GP_df, on="timestamp_unix", how="outer")
    df_hard_merged.drop('window', axis=1, inplace=True) # No longer need this column, as it was used for validation

    numeric_cols = df_hard_merged.select_dtypes(include=['number']).columns
    for n in numeric_cols:
        df_hard_merged[n] = df_hard_merged[n].interpolate()

    # Dropping rows with values (Trimming the start of dataframes if null values exist after merging)
    df_hard_merged = df_hard_merged.dropna().reset_index(drop=True)

    df_hard_merged.to_csv(os.path.join(participant_dir, f"participant{p}_hard_assessment.csv"), index=False)
    print('\t\tSuccessfully merged hard asessment data')
# Out:
# Participant 4
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 5
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 6
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 7
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 8
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 9
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 10
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 11
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 12
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 13
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 14
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 15
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 16
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 17
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 18
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 19
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 20
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 21
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 22
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 23
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 24
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 25
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data
# Participant 26
# 		Successfully merged easy asessment data
# 		Successfully merged hard asessment data

# %% [markdown]
# Validating start and end times for all merged data files

# %%
for participant in os.listdir(MERGED_DATA):
    print(participant)
    for file in os.listdir(os.path.join(MERGED_DATA, participant)):
        print(f"\t{file}", end=" ")
        df = pd.read_csv(os.path.join(MERGED_DATA, participant, file))

        # Converting UNIX timestamp to Pacific time readable format
        pacific_timezone = pytz.timezone('US/Pacific')
        df['timestamp_pst'] = df['timestamp_unix'].apply(lambda x: datetime.fromtimestamp(x / 1000, pacific_timezone).strftime('%I:%M:%S %p'))

        start, end = df.iloc[0]['timestamp_pst'], df.iloc[-1]['timestamp_pst']

        print(f"Shape: \033[32m {df.shape} \033[0m | Times: \033[94m [[{start} - {end}]] \033[0m")
# Out:
# Participant 4
# 	participant4_easy_assessment.csv Shape:  (78, 66)  | Times:  [[04:41:00 PM - 04:51:55 PM]]
# 	participant4_hard_assessment.csv Shape:  (185, 66)  | Times:  [[05:03:00 PM - 05:29:15 PM]]
# Participant 5
# 	participant5_easy_assessment.csv Shape:  (56, 66)  | Times:  [[10:11:00 AM - 10:18:55 AM]]
# 	participant5_hard_assessment.csv Shape:  (190, 66)  | Times:  [[10:29:00 AM - 10:55:56 AM]]
# Participant 6
# 	participant6_easy_assessment.csv Shape:  (48, 66)  | Times:  [[07:27:00 PM - 07:33:34 PM]]
# 	participant6_hard_assessment.csv Shape:  (132, 66)  | Times:  [[07:42:04 PM - 08:00:44 PM]]
# Participant 7
# 	participant7_easy_assessment.csv Shape:  (46, 66)  | Times:  [[11:32:00 AM - 11:38:14 AM]]
# 	participant7_hard_assessment.csv Shape:  (105, 66)  | Times:  [[11:45:00 AM - 11:59:46 AM]]
# Participant 8
# 	participant8_easy_assessment.csv Shape:  (56, 66)  | Times:  [[01:54:00 PM - 02:01:51 PM]]
# 	participant8_hard_assessment.csv Shape:  (206, 66)  | Times:  [[02:11:00 PM - 02:40:11 PM]]
# Participant 9
# 	participant9_easy_assessment.csv Shape:  (41, 66)  | Times:  [[03:53:00 PM - 03:58:44 PM]]
# 	participant9_hard_assessment.csv Shape:  (175, 66)  | Times:  [[04:06:00 PM - 04:30:50 PM]]
# Participant 10
# 	participant10_easy_assessment.csv Shape:  (61, 66)  | Times:  [[06:03:00 PM - 06:11:33 PM]]
# 	participant10_hard_assessment.csv Shape:  (136, 66)  | Times:  [[06:20:00 PM - 06:39:16 PM]]
# Participant 11
# 	participant11_easy_assessment.csv Shape:  (45, 66)  | Times:  [[11:35:00 AM - 11:41:04 AM]]
# 	participant11_hard_assessment.csv Shape:  (157, 66)  | Times:  [[11:51:00 AM - 12:13:16 PM]]
# Participant 12
# 	participant12_easy_assessment.csv Shape:  (65, 66)  | Times:  [[01:26:09 PM - 01:35:14 PM]]
# 	participant12_hard_assessment.csv Shape:  (149, 66)  | Times:  [[01:44:01 PM - 02:05:08 PM]]
# Participant 13
# 	participant13_easy_assessment.csv Shape:  (99, 66)  | Times:  [[01:29:06 PM - 01:43:01 PM]]
# 	participant13_hard_assessment.csv Shape:  (248, 66)  | Times:  [[01:52:00 PM - 02:27:10 PM]]
# Participant 14
# 	participant14_easy_assessment.csv Shape:  (62, 66)  | Times:  [[12:04:00 PM - 12:12:39 PM]]
# 	participant14_hard_assessment.csv Shape:  (163, 66)  | Times:  [[11:32:00 AM - 11:55:00 AM]]
# Participant 15
# 	participant15_easy_assessment.csv Shape:  (34, 66)  | Times:  [[08:00:08 PM - 08:04:51 PM]]
# 	participant15_hard_assessment.csv Shape:  (146, 66)  | Times:  [[07:24:00 PM - 07:44:47 PM]]
# Participant 16
# 	participant16_easy_assessment.csv Shape:  (60, 66)  | Times:  [[12:06:00 PM - 12:14:20 PM]]
# 	participant16_hard_assessment.csv Shape:  (137, 66)  | Times:  [[11:38:00 AM - 11:57:25 AM]]
# Participant 17
# 	participant17_easy_assessment.csv Shape:  (53, 66)  | Times:  [[01:44:00 PM - 01:51:20 PM]]
# 	participant17_hard_assessment.csv Shape:  (58, 66)  | Times:  [[01:26:00 PM - 01:34:04 PM]]
# Participant 18
# 	participant18_easy_assessment.csv Shape:  (47, 66)  | Times:  [[01:41:00 PM - 01:47:32 PM]]
# 	participant18_hard_assessment.csv Shape:  (147, 66)  | Times:  [[01:11:00 PM - 01:31:56 PM]]
# Participant 19
# 	participant19_easy_assessment.csv Shape:  (33, 66)  | Times:  [[01:40:00 PM - 01:44:35 PM]]
# 	participant19_hard_assessment.csv Shape:  (48, 66)  | Times:  [[01:20:00 PM - 01:26:37 PM]]
# Participant 20
# 	participant20_easy_assessment.csv Shape:  (56, 66)  | Times:  [[12:05:00 PM - 12:12:50 PM]]
# 	participant20_hard_assessment.csv Shape:  (150, 66)  | Times:  [[11:35:00 AM - 11:56:07 AM]]
# Participant 21
# 	participant21_easy_assessment.csv Shape:  (61, 66)  | Times:  [[02:13:00 PM - 02:21:28 PM]]
# 	participant21_hard_assessment.csv Shape:  (196, 66)  | Times:  [[01:30:00 PM - 01:57:53 PM]]
# Participant 22
# 	participant22_easy_assessment.csv Shape:  (81, 66)  | Times:  [[01:32:00 PM - 01:43:19 PM]]
# 	participant22_hard_assessment.csv Shape:  (192, 66)  | Times:  [[12:55:00 PM - 01:22:07 PM]]
# Participant 23
# 	participant23_easy_assessment.csv Shape:  (66, 66)  | Times:  [[03:13:00 PM - 03:22:12 PM]]
# 	participant23_hard_assessment.csv Shape:  (235, 66)  | Times:  [[02:28:00 PM - 03:01:16 PM]]
# Participant 24
# 	participant24_easy_assessment.csv Shape:  (53, 66)  | Times:  [[05:21:00 PM - 05:28:13 PM]]
# 	participant24_hard_assessment.csv Shape:  (144, 66)  | Times:  [[05:38:08 PM - 05:58:29 PM]]
# Participant 25
# 	participant25_easy_assessment.csv Shape:  (68, 66)  | Times:  [[08:19:00 PM - 08:28:28 PM]]
# 	participant25_hard_assessment.csv Shape:  (185, 66)  | Times:  [[07:34:00 PM - 08:00:07 PM]]
# Participant 26
# 	participant26_easy_assessment.csv Shape:  (34, 66)  | Times:  [[10:59:00 AM - 11:03:36 AM]]
# 	participant26_hard_assessment.csv Shape:  (123, 66)  | Times:  [[10:32:00 AM - 10:49:13 AM]]

# %% [markdown]
# Checking for null data after merging:

# %%
for participant in os.listdir(MERGED_DATA):
    print(participant)
    for file in os.listdir(os.path.join(MERGED_DATA, participant)):
        print(f"\t{file}", end=" ")
        df = pd.read_csv(os.path.join(MERGED_DATA, participant, file))
        total_rows = len(df)

        # Finding columns with null values and their null count
        columns_with_nulls = df.isnull().sum()
        columns_with_nulls = columns_with_nulls[columns_with_nulls > 0]  # Filter columns with at least one null

        # Formatting the output
        output = ", ".join([f"{col} ({null_count}/{total_rows})" for col, null_count in columns_with_nulls.items()])

        # Printing the result
        print(f"Columns with null values: {output}")
# Out:
# Participant 4
# 	participant4_easy_assessment.csv Columns with null values:
# 	participant4_hard_assessment.csv Columns with null values:
# Participant 5
# 	participant5_easy_assessment.csv Columns with null values:
# 	participant5_hard_assessment.csv Columns with null values:
# Participant 6
# 	participant6_easy_assessment.csv Columns with null values:
# 	participant6_hard_assessment.csv Columns with null values:
# Participant 7
# 	participant7_easy_assessment.csv Columns with null values:
# 	participant7_hard_assessment.csv Columns with null values:
# Participant 8
# 	participant8_easy_assessment.csv Columns with null values:
# 	participant8_hard_assessment.csv Columns with null values:
# Participant 9
# 	participant9_easy_assessment.csv Columns with null values:
# 	participant9_hard_assessment.csv Columns with null values:
# Participant 10
# 	participant10_easy_assessment.csv Columns with null values:
# 	participant10_hard_assessment.csv Columns with null values:
# Participant 11
# 	participant11_easy_assessment.csv Columns with null values:
# 	participant11_hard_assessment.csv Columns with null values:
# Participant 12
# 	participant12_easy_assessment.csv Columns with null values:
# 	participant12_hard_assessment.csv Columns with null values:
# Participant 13
# 	participant13_easy_assessment.csv Columns with null values:
# 	participant13_hard_assessment.csv Columns with null values:
# Participant 14
# 	participant14_easy_assessment.csv Columns with null values:
# 	participant14_hard_assessment.csv Columns with null values:
# Participant 15
# 	participant15_easy_assessment.csv Columns with null values:
# 	participant15_hard_assessment.csv Columns with null values:
# Participant 16
# 	participant16_easy_assessment.csv Columns with null values:
# 	participant16_hard_assessment.csv Columns with null values:
# Participant 17
# 	participant17_easy_assessment.csv Columns with null values:
# 	participant17_hard_assessment.csv Columns with null values:
# Participant 18
# 	participant18_easy_assessment.csv Columns with null values:
# 	participant18_hard_assessment.csv Columns with null values:
# Participant 19
# 	participant19_easy_assessment.csv Columns with null values:
# 	participant19_hard_assessment.csv Columns with null values:
# Participant 20
# 	participant20_easy_assessment.csv Columns with null values:
# 	participant20_hard_assessment.csv Columns with null values:
# Participant 21
# 	participant21_easy_assessment.csv Columns with null values:
# 	participant21_hard_assessment.csv Columns with null values:
# Participant 22
# 	participant22_easy_assessment.csv Columns with null values:
# 	participant22_hard_assessment.csv Columns with null values:
# Participant 23
# 	participant23_easy_assessment.csv Columns with null values:
# 	participant23_hard_assessment.csv Columns with null values:
# Participant 24
# 	participant24_easy_assessment.csv Columns with null values:
# 	participant24_hard_assessment.csv Columns with null values:
# Participant 25
# 	participant25_easy_assessment.csv Columns with null values:
# 	participant25_hard_assessment.csv Columns with null values:
# Participant 26
# 	participant26_easy_assessment.csv Columns with null values:
# 	participant26_hard_assessment.csv Columns with null values:
